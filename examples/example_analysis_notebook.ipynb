# %% [markdown]
# # Personal Stock Research Assistent Demo

# %% [markdown]
# **Author:** Arash Mirshahi
# **Course:** Agents Intensive - Capstone Project
# **Date:** November 2025

# %% [markdown]
# ## Overview
#
# This notebook demonstrates a sophisticated multi-agent system that automates comprehensive stock research analysis.
#
# ### Key Features:
# - 🤖 **4 Specialized AI Agents** working in coordinated workflow
# - 📊 **Real-time Financial Data** from Yahoo Finance
# - 📰 **News Sentiment Analysis** using LLM
# - 🔄 **Parallel & Sequential Execution** via LangGraph
# - 💾 **Session Memory** for conversation context
#
# ### Technologies Used:
# - **LangGraph** - Multi-agent orchestration
# - **Google Gemini Flash** - LLM reasoning (free tier)
# - **yfinance** - Financial data API
# - **NewsAPI** - Real-time news aggregation

# %% [markdown]
# ## Initial Setup

# %%
import sys
from pathlib import Path

# Add parent directory (project root) to Python path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

print(f"✅ Project root added to path: {project_root}")
# Out:
# ✅ Project root added to path: c:\Users\arash\Desktop\Stock_Analysis_Agents

# %%
# Install required packages (uncomment to run):
# pip install -r requirements.txt
print("Requirements Installed.")

# Import Libraries:
import os
import time
from dotenv import load_dotenv
from agents.orchestrator import create_stock_research_agent
from agents.state import AgentState
print("Libraries Imported.")

# Load API keys from .env file:
load_dotenv()
print("Environment Variables Loaded.")
# Out:
# Requirements Installed.
# Libraries Imported.
# Environment Variables Loaded.

# %% [markdown]
# ## State Explanation

# %% [markdown]
# In multi-agent systems, **state** is like a shared notebook that all agents can read and write to.
#
# Here's what our shared notebook looks like:

# %%
# Show the initial state structure
initial_state = {
    'user_query': '',           # What you asked
    'ticker': '',               # Stock symbol (e.g., "NVDA")
    'company_name': '',         # Full name (e.g., "NVIDIA Corporation")
    'financial_data': None,     # Prices, P/E ratio, etc.
    'sentiment_data': None,     # News analysis
    'sentiment_score': None,    # Number from -1 (bad) to +1 (good)
    'final_report': None,       # The full analysis
    'recommendation': None,     # BUY, HOLD, or SELL
    'errors': []                # Any problems that happened
}

print("📝 This is what gets passed between agents!")
print(initial_state)
# Out:
# 📝 This is what gets passed between agents!
# {'user_query': '', 'ticker': '', 'company_name': '', 'financial_data': None, 'sentiment_data': None, 'sentiment_score': None, 'final_report': None, 'recommendation': None, 'errors': []}

# %% [markdown]
# # Create The Helper Function

# %% [markdown]
# Let's make a simple function to run our analysis:

# %%
def analyze_stock(query):
    """
    Analyzes a stock based on your question.
    
    Args:
        query: Your question (e.g., "Should I buy Apple?")
    
    Returns:
        Dictionary with the analysis results
    """
    # Create the agent system
    agent = create_stock_research_agent()
    
    # Start with empty state
    state = {
        'user_query': query,
        'ticker': '',
        'company_name': '',
        'financial_data': None,
        'sentiment_data': None,
        'sentiment_score': None,
        'final_report': None,
        'recommendation': None,
        'errors': []
    }
    
    print(f"🔍 Starting analysis: '{query}'")
    print("⏳ This will take ~15-25 seconds...\n")
    
    # Run the multi-agent workflow
    start_time = time.time()
    result = agent.invoke(state)
    end_time = time.time()
    
    print(f"✅ Done in {end_time - start_time:.2f} seconds!\n")
    
    return result

print("✅ Helper function created!")
# Out:
# ✅ Helper function created!

# %% [markdown]
# # Understanding the Query Parser
#
# One of the coolest parts is that our system understands natural language!
#
# Let's test it with different ways of asking about the same stock:

# %%
# Test 1: Uppercase ticker
print("Test 1: Direct ticker symbol")
result1 = analyze_stock("analyze NVDA")
print(f"   Understood ticker: {result1['ticker']}")
print(f"   Company: {result1['company_name']}\n")

# Cell 10: More Query Parser Tests
# Test 2: Lowercase
print("Test 2: Lowercase ticker")
result2 = analyze_stock("what about nvda?")
print(f"   Understood ticker: {result2['ticker']}\n")

# Test 3: Company name
print("Test 3: Using company name")
result3 = analyze_stock("tell me about NVIDIA")
print(f"   Understood ticker: {result3['ticker']}")
print(f"   Company: {result3['company_name']}\n")

print("🎯 The LLM successfully parsed all 3 formats!")
# Out:
# INFO:agents.orchestrator:✅ Stock Research Agent workflow created successfully
# INFO:agents.orchestrator:🔍 Orchestrator: Parsing query: 'analyze NVDA'
# Test 1: Direct ticker symbol
# 🔍 Starting analysis: 'analyze NVDA'
# ⏳ This will take ~10-15 seconds...
# INFO:agents.orchestrator:✅ Orchestrator: Extracted ticker: NVDA
# INFO:agents.orchestrator:🔄 Orchestrator: Running data collection agents...
# INFO:agents.financial_agent:💰 Financial Data Agent: Fetching data for NVDA
# INFO:agents.financial_agent:✅ Financial Data Agent: Successfully retrieved data for NVDA
# INFO:agents.financial_agent:   Current Price: $181.36
# INFO:agents.financial_agent:   P/E Ratio: 51.522728
# INFO:agents.sentiment_agent:📰 Sentiment Analysis Agent: Analyzing sentiment for NVIDIA Corporation
# INFO:agents.sentiment_agent:✅ Sentiment Analysis Agent: Score = 0.00
# INFO:agents.sentiment_agent:   Analyzed 20 articles
# INFO:agents.orchestrator:✅ Orchestrator: Data collection complete
# INFO:agents.report_agent:📝 Report Generator Agent: Creating report for NVIDIA Corporation
# INFO:agents.report_agent:✅ Report Generator Agent: Report created
# INFO:agents.report_agent:   Recommendation: BUY
# INFO:agents.orchestrator:✅ Stock Research Agent workflow created successfully
# INFO:agents.orchestrator:🔍 Orchestrator: Parsing query: 'what about nvda?'
# ✅ Done in 18.87 seconds!
#
#    Understood ticker: NVDA
#    Company: NVIDIA Corporation
#
# Test 2: Lowercase ticker
# 🔍 Starting analysis: 'what about nvda?'
# ⏳ This will take ~10-15 seconds...
# INFO:agents.orchestrator:✅ Orchestrator: Extracted ticker: NVDA
# INFO:agents.orchestrator:🔄 Orchestrator: Running data collection agents...
# INFO:agents.financial_agent:💰 Financial Data Agent: Fetching data for NVDA
# INFO:agents.financial_agent:✅ Financial Data Agent: Successfully retrieved data for NVDA
# INFO:agents.financial_agent:   Current Price: $181.36
# INFO:agents.financial_agent:   P/E Ratio: 51.522728
# INFO:agents.sentiment_agent:📰 Sentiment Analysis Agent: Analyzing sentiment for NVIDIA Corporation
# INFO:agents.sentiment_agent:✅ Sentiment Analysis Agent: Score = 0.00
# INFO:agents.sentiment_agent:   Analyzed 20 articles
# INFO:agents.orchestrator:✅ Orchestrator: Data collection complete
# INFO:agents.report_agent:📝 Report Generator Agent: Creating report for NVIDIA Corporation
# INFO:agents.report_agent:✅ Report Generator Agent: Report created
# INFO:agents.report_agent:   Recommendation: BUY
# INFO:agents.orchestrator:✅ Stock Research Agent workflow created successfully
# INFO:agents.orchestrator:🔍 Orchestrator: Parsing query: 'tell me about NVIDIA'
# ✅ Done in 18.88 seconds!
#
#    Understood ticker: NVDA
#
# Test 3: Using company name
# 🔍 Starting analysis: 'tell me about NVIDIA'
# ⏳ This will take ~10-15 seconds...
# INFO:agents.orchestrator:✅ Orchestrator: Extracted ticker: NVDA
# INFO:agents.orchestrator:🔄 Orchestrator: Running data collection agents...
# INFO:agents.financial_agent:💰 Financial Data Agent: Fetching data for NVDA
# INFO:agents.financial_agent:✅ Financial Data Agent: Successfully retrieved data for NVDA
# INFO:agents.financial_agent:   Current Price: $181.36
# INFO:agents.financial_agent:   P/E Ratio: 51.522728
# INFO:agents.sentiment_agent:📰 Sentiment Analysis Agent: Analyzing sentiment for NVIDIA Corporation
# INFO:agents.sentiment_agent:✅ Sentiment Analysis Agent: Score = 0.75
# INFO:agents.sentiment_agent:   Analyzed 20 articles
# INFO:agents.orchestrator:✅ Orchestrator: Data collection complete
# INFO:agents.report_agent:📝 Report Generator Agent: Creating report for NVIDIA Corporation
# INFO:agents.report_agent:✅ Report Generator Agent: Report created
# INFO:agents.report_agent:   Recommendation: BUY
# ✅ Done in 17.05 seconds!
#
#    Understood ticker: NVDA
#    Company: NVIDIA Corporation
#
# 🎯 The LLM successfully parsed all 3 formats!

# %% [markdown]
# # Deep Dive - What Happens Behind the Scenes?

# %% [markdown]
# Let me explain the workflow step by step:
#
# ### Step 1: Orchestrator Receives Query
# Your question: *"tell me about NVIDIA"*
#
# The Orchestrator uses Gemini LLM to understand:
# - Is this a stock question? ✅
# - What's the ticker symbol? → "NVDA"
#
# ### Step 2: Parallel Execution (Both run at same time!)
#
# **Financial Data Agent:**
# - Calls Yahoo Finance API
# - Gets: price, P/E ratio, market cap, etc.
# - Takes ~3 seconds
#
# **Sentiment Analysis Agent:**
# - Calls NewsAPI
# - Fetches last 20 articles about NVIDIA
# - Uses LLM to analyze sentiment
# - Takes ~10 seconds
#
# ### Step 3: Report Generator (Waits for both)
# - Receives financial data
# - Receives sentiment data
# - Uses LLM to write comprehensive report
# - Takes ~8 seconds
#
# **Total: ~18 seconds**

# %% [markdown]
# # Full Analysis Example - META
#
# Now let's do a full analysis on META stock (my favorite stock in my portfolio) and look at all the data we get:

# %%
meta_result = analyze_stock("Should I invest in meta?")
# Out:
# INFO:agents.orchestrator:✅ Stock Research Agent workflow created successfully
# INFO:agents.orchestrator:🔍 Orchestrator: Parsing query: 'Should I invest in meta?'
# 🔍 Starting analysis: 'Should I invest in meta?'
# ⏳ This will take ~15-25 seconds...
# INFO:agents.orchestrator:✅ Orchestrator: Extracted ticker: META
# INFO:agents.orchestrator:🔄 Orchestrator: Running data collection agents...
# INFO:agents.financial_agent:💰 Financial Data Agent: Fetching data for META
# INFO:agents.financial_agent:✅ Financial Data Agent: Successfully retrieved data for META
# INFO:agents.financial_agent:   Current Price: $588.0862
# INFO:agents.financial_agent:   P/E Ratio: 26.02988
# INFO:agents.sentiment_agent:📰 Sentiment Analysis Agent: Analyzing sentiment for Meta Platforms, Inc.
# INFO:agents.sentiment_agent:✅ Sentiment Analysis Agent: Score = 0.25
# INFO:agents.sentiment_agent:   Analyzed 20 articles
# INFO:agents.orchestrator:✅ Orchestrator: Data collection complete
# INFO:agents.report_agent:📝 Report Generator Agent: Creating report for Meta Platforms, Inc.
# INFO:agents.report_agent:✅ Report Generator Agent: Report created
# INFO:agents.report_agent:   Recommendation: BUY
# ✅ Done in 20.46 seconds!

# %%
financial = meta_result['financial_data']

# %%
print(f"Current Price: ${financial['current_price']}")
print(f"Market Cap: ${financial['market_cap']:,}")
print(f"P/E Ratio: {financial['pe_ratio']}")
print(f"Profit Margin: {financial['profit_margin']}")
print(f"52-Week High: ${financial['fifty_two_week_high']}")
print(f"52-Week Low: ${financial['fifty_two_week_low']}")
# Out:
# Current Price: $588.0862
# Market Cap: $1,482,108,043,264
# P/E Ratio: 26.02988
# Profit Margin: 0.30892
# 52-Week High: $796.25
# 52-Week Low: $479.8

# %%
sentiment = meta_result['sentiment_data']

# %%
print(f"Articles Analyzed: {sentiment['article_count']}")
print(f"Overall Sentiment: {sentiment['sentiment_score']:.2f}")
print(f"Summary: {sentiment['summary']}\n")
# Out:
# Articles Analyzed: 20
# Overall Sentiment: 0.25
# Summary: The overall sentiment is slightly positive, driven by strong analyst confidence, including a bullish target upgrade and high-profile endorsements from Jim Cramer, who stated he is "long" Meta. This optimism is significantly tempered by negative news concerning legal risks, specifically a social media addiction lawsuit against Instagram, and reports of internal executive drama and turnover related to the company's heavy capital investments in AI infrastructure.

# %%
print("Top 3 Headlines:")
for i, article in enumerate(sentiment['articles'][:3], 1):
    print(f"{i}. {article['title']}")
    print(f"   Source: {article['source']}\n")
# Out:
# Top 3 Headlines:
# 1. Burry’s Depreciation Gripe Shines Spotlight on Big Tech Profits
#    Source: Yahoo Entertainment
#
# 2. “You Don’t Go After This Guy,” Says Jim Cramer About Meta (META) CEO Mark Zuckerberg
#    Source: Yahoo Entertainment
#
# 3. Jim Cramer Says “We Are Long Meta for the Charitable Trust”
#    Source: Yahoo Entertainment

# %% [markdown]
# # The Final Report
#
# Here's the comprehensive analysis that the Report Generator created:

# %%
print(meta_result['final_report'])
# Out:
# # Stock Analysis Report: Meta Platforms, Inc. (META)
#
# ## 1. Executive Summary
#
# **Recommendation: BUY**
#
# Meta Platforms, Inc. (META) presents a compelling investment case driven by exceptionally strong profitability, a dominant position in digital advertising, and aggressive strategic investments in Artificial Intelligence (AI) infrastructure. The current valuation, while robust, appears justified by the 30.89% profit margin and significant earnings per share (EPS) of $22.59.
#
# The consensus among professional analysts is a **STRONG BUY**. However, investors must be cognizant of material legal and operational risks, particularly concerning social media addiction litigation and the high capital expenditure associated with the AI pivot. The current price of $588.09 is significantly below the 52-week high of $796.25, offering substantial potential upside if the company successfully navigates its legal challenges and demonstrates early monetization success from its AI initiatives.
#
# | Metric | Value | Commentary |
# | :--- | :--- | :--- |
# | Current Price | $588.09 | Significant upside potential to 52-week high. |
# | P/E Ratio | 26.03x | Reasonable valuation for a high-growth tech leader. |
# | Profit Margin | 30.89% | Excellent operational efficiency and pricing power. |
# | Analyst Consensus | STRONG\_BUY | High confidence in future performance. |
#
# ---
#
# ## 2. Financial Analysis
#
# ### Valuation and Profitability
#
# Meta Platforms maintains a massive scale, evidenced by its Market Capitalization of approximately $1.48 Trillion.
#
# **Earnings and Valuation:**
# The P/E Ratio stands at 26.03. When compared to the broader technology sector, this valuation is attractive, particularly given the company's established market dominance and high growth potential in its core services (Facebook, Instagram, WhatsApp). The strong Earnings Per Share (EPS) of $22.59 underscores the company's ability to generate substantial net income.
#
# **Operational Efficiency:**
# The most impressive financial metric is the **Profit Margin of 30.892%**. This indicates superior operational efficiency and pricing power within the digital advertising ecosystem. A profit margin exceeding 30% for a company of this size suggests effective cost management and a successful transition away from the heavy operational losses previously associated with the Metaverse division.
#
# ### Price Performance and Volatility
#
# META is currently trading at $588.09, placing it closer to the midpoint of its 52-week range:
#
# *   **52-Week High:** $796.25
# *   **52-Week Low:** $479.80
#
# The current price point suggests that the stock has experienced significant volatility following its peak. The potential upside to re-test the 52-week high is approximately 35.4%, indicating a favorable risk/reward profile for investors willing to tolerate medium-term volatility.
#
# ---
#
# ## 3. Market Sentiment
#
# The overall market sentiment toward META is **Slightly Positive (Score: 0.25)**, based on the analysis of 20 recent articles. The sentiment is characterized by a strong dichotomy: high confidence in the financial future balanced by serious concerns regarding legal and internal stability.
#
# ### Bullish Drivers
#
# 1.  **Analyst Confidence:** The formal analyst recommendation is a **STRONG BUY**, supported by recent bullish target upgrades. This confidence is rooted in the performance of the core advertising business and the long-term potential of AI integration across its platforms.
# 2.  **High-Profile Endorsements:** Public support from influential figures, such as Jim Cramer stating he is "long" Meta, reinforces the bullish narrative that the company is fundamentally sound and strategically positioned for future growth.
#
# ### Bearish/Tempering Drivers
#
# 1.  **Legal Risks:** A significant headwind is the growing legal risk associated with social media addiction lawsuits, specifically targeting Instagram. These lawsuits pose a threat of substantial financial penalties and potential regulatory limitations on platform design and usage.
# 2.  **Operational Instability:** Reports of internal executive drama and turnover are tempering enthusiasm. This suggests potential instability or disagreement regarding the strategic direction, particularly concerning the massive capital investments required for AI infrastructure build-out.
#
# ---
#
# ## 4. Risk Assessment
#
# While the financial outlook is strong, several material risks could impact META's performance:
#
# ### A. Legal and Regulatory Risk (High)
# The primary legal threat is the social media addiction litigation. A negative outcome could lead to billions in liabilities and force fundamental changes to the core product design, potentially impacting user engagement and, consequently, advertising revenue. Furthermore, global regulatory scrutiny regarding data privacy and content moderation remains a constant threat.
#
# ### B. Operational and Strategic Risk (Medium-High)
# META is currently undergoing a massive, costly pivot toward generative AI. The heavy capital investments required for this infrastructure pose two risks:
# 1.  **Execution Risk:** Failure to successfully integrate and monetize these AI capabilities quickly could lead to investor disappointment regarding CapEx efficiency.
# 2.  **Talent/Stability Risk:** Reports of executive drama suggest internal friction, which could delay projects or lead to poor strategic decisions if key leadership is unstable.
#
# ### C. Market Risk (Medium)
# META's revenue is heavily dependent on the global digital advertising market. While resilient, any macro-economic downturn that reduces corporate advertising budgets could immediately impact META's top line. The stock's history of volatility suggests sharp pullbacks are possible following any earnings miss or negative news cycle.
#
# ---
#
# ## 5. Conclusion
#
# Meta Platforms, Inc. (META) is a financially robust technology leader trading at a reasonable valuation (P/E 26.03) given its exceptional profitability (30.89% Profit Margin). The company is leveraging its dominant market position to aggressively invest in the next wave of technology (AI), which, if successful, promises significant long-term growth.
#
# The strong analyst consensus and the significant gap between the current price ($588.09) and the 52-week high ($796.25) provide a compelling entry point for growth-oriented investors.
#
# **Investment Recommendation:** **BUY**.
#
# The recommendation is predicated on the belief that the strength of the core advertising business and the long-term strategic value of the AI investments will outweigh the material, but manageable, risks posed by legal challenges and internal operational friction. Investors should monitor developments related to the Instagram addiction lawsuit closely, as this represents the most significant near-term threat to the investment thesis.

# %% [markdown]
# # Error Handling
#
# What happens if we ask about something that's not a stock?

# %%
bad_result = analyze_stock("what's the weather today?")
# Out:
# INFO:agents.orchestrator:✅ Stock Research Agent workflow created successfully
# INFO:agents.orchestrator:🔍 Orchestrator: Parsing query: 'what's the weather today?'
# 🔍 Starting analysis: 'what's the weather today?'
# ⏳ This will take ~15-25 seconds...
# ERROR:agents.orchestrator:❌ Orchestrator: Could not extract ticker from query
# ✅ Done in 0.44 seconds!

# %%
if bad_result['ticker'] == 'UNKNOWN':
    print("❌ The system correctly identified this as invalid!")
    print(f"Error: {bad_result['errors'][0]}")
else:
    print("Unexpected result - system should have rejected this")
# Out:
# ❌ The system correctly identified this as invalid!
# Error: Could not identify stock ticker in query: 'what's the weather today?'. Please mention a specific stock ticker or company name.

# %% [markdown]
# # Conclusion
#
# ### What was built?
#
# A production-ready multi-agent system that automates 95% of stock research work.
#
# Time Savings:
# - Manual: 3-5 hours
# - Automated: ~15 seconds
# - Savings: 99%
#
# Real-World Value:
# - This system could genuinely help individual investors make faster, more informed decisions.
